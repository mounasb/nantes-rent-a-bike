# %%
import json
import requests
import pandas as pd
import folium

# %%
# API request : real-time data showing filling rate of Nantes' rent-a-bike stations
link = "https://data.nantesmetropole.fr/api/records/1.0/search/?dataset=244400404_stations-velos-libre-service-nantes-metropole-disponibilites&rows=-1"
r = requests.get(link)
data = json.loads(r.text)

# %%
bikes = pd.json_normalize(r.json(),
                  record_path = 'records')

# %%
bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   datasetid                     127 non-null    object
#  1   recordid                      127 non-null    object
#  2   fields.available_bike_stands  127 non-null    int64
#  3   fields.bike_stands            127 non-null    int64
#  4   fields.number                 127 non-null    int64
#  5   fields.address                127 non-null    object
#  6   fields.name                   127 non-null    object
#  7   fields.bonus                  127 non-null    object
#  8   fields.banking                127 non-null    object
#  9   fields.contract_name          127 non-null    object
#  10  fields.status                 127 non-null    object
#  11  fields.available_bikes        127 non-null    int64
#  12  fields.position               127 non-null    object
#  13  fields.last_update            127 non-null    object
#  14  geometry.type                 127 non-null    object
#  15  geometry.coordinates          127 non-null    object
# dtypes: int64(4), object(12)
# memory usage: 16.0+ KB

# %%
columns_to_keep = ['fields.available_bike_stands', 'fields.bike_stands', 'fields.address', 'fields.name', 'fields.status', 'fields.available_bikes', 'fields.position']
bikes = bikes[columns_to_keep]
bikes.head(2)
# Out:
#    fields.available_bike_stands  fields.bike_stands  \
# 0                             6                  14
# 1                            18                  30
#
#                           fields.address              fields.name  \
# 0  18, rue Talensac - 26, rue de Bel Air        071-TALENSAC NORD
# 1              16, boulevard Jules Verne  120-ROND-POINT DE PARIS
#
#   fields.status  fields.available_bikes                        fields.position
# 0          OPEN                       8  [47.2218536381884, -1.55894074669074]
# 1          OPEN                      12                 [47.234853, -1.534981]

# %%
# Builds a map, adds a marker for each station
# Displays number of availables bikes & bike stands
# Markers' color and icon depend on stations' status and the number of available bikes

centre = [47.217212, -1.543517]     # station "060 - GARE DE NANTES NORD 2"
m = folium.Map(location=centre, zoom_start=14)

for i in range(len(bikes)):
  status = bikes.loc[i]['fields.status']
  velos_dispo = bikes.loc[i]['fields.available_bikes']
  places_dispo = bikes.loc[i]['fields.available_bike_stands']
  loc = bikes.loc[i]['fields.position']
  tip = folium.Tooltip(f"<b>{bikes.loc[i]['fields.name']}</b><br>• {velos_dispo} vélo(s) disponible(s)<br>• {places_dispo} place(s) disponible(s)")
  seuil_max = 3

  if status == 'CLOSED':
    icon = folium.Icon(color='gray', icon='glyphicon-remove')
    tip = folium.Tooltip(f"<b>{bikes.loc[i]['fields.name']}</b><br>• STATION FERMÉE")
  else:
    if velos_dispo == 0:
      icon = folium.Icon(color='red', icon="glyphicon-ban-circle")
    elif velos_dispo <= seuil_max:
      icon = folium.Icon(color="orange", icon="glyphicon-exclamation-sign")
    else:
      icon = folium.Icon(color='darkblue', icon="bicycle", prefix="fa")

  folium.Marker(
    location=loc,
    tooltip = tip,
    icon=icon
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c4bec57c9e6578bec0a227c3a5f76c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c4bec57c9e6578bec0a227c3a5f76c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2c4bec57c9e6578bec0a227c3a5f76c4 = L.map(
#                 &quot;map_2c4bec57c9e6578bec0a227c3a5f76c4&quot;,
#                 {
#                     center: [47.217212, -1.543517],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_976b661610c50c737cb2c1e89add00d3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2c4bec57c9e6578bec0a227c3a5f76c4);
#
#
#             var marker_6ffe2fc453f8ef5827fc94b67d9bafae = L.marker(
#                 [47.2218536381884, -1.55894074669074],
#                 {}
#             ).addTo(map_2c4bec57c9e6578bec0a227c3a5f76c4);
#
#
#             var icon_5c8a5547b4b6e77bb969614f9a7e229b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6ffe2fc453f8ef5827fc94b67d9bafae.setIcon(icon_5c8a5547b4b6e77bb969614f9a7e229b);
#
#
#             marker_6ffe2fc453f8ef5827fc94b67d9bafae.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;071-TALENSAC NORD&lt;/b&gt;&lt;br&gt;• 8 vélo(s) disponible(s)&lt;br&gt;• 6 place(s) disponible(s)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_25fd8f1e771a8e60e9dc84a67a55d535 = L.marker(
#                 [47.234853, -1.534981],
#                 {}
#             ).addTo(map_2c4bec57c9e6578bec0a227c3a5f76c4);
#
#
#             var icon_cf2da9a8a1980936a38bc663fc890ec6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_25fd8f1e771a8e60e9dc84a67a55d535.setIcon(icon_cf2da9a8a1980936a38bc663fc890ec6);
#
#
#             marker_25fd8f1e771a8e60e9dc84a67a55d535.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;120-ROND-POINT DE PARIS&lt;/b&gt;&lt;br&gt;• 12 vélo(s) disponible(s)&lt;br&gt;• 18 place(s) disponible(s)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_51d2baa995c6c3e810b1705605880d07 = L.marker(
#                 [47.2166675820152, -1.5543847138777],
#                 {}
#             ).addTo(map_2c4bec57c9e6578bec0a227c3a5f76c4);
#
#
#             var icon_58203543057d5ef2bc10f6709a63132d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-exclamation-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_51d2baa995c6c3e810b1705605880d07.setIcon(icon_58203543057d5ef2bc10f6709a63132d);
#
#
#             marker_51d2baa995c6c3e810b1705605880d07.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;004-MOULIN&lt;/b&gt;&lt;br&gt;• 3 vélo(s) disponible(s)&lt;br&gt;• 12 place(s) disponible(s)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3fd7c1e39137b719741c2294e2339353 = L.marker(
#                 [47.2158145871395, -1.55901748516744],
#                 {}
#             ).addTo(map_2c4bec57c9e6578bec0a227c3a5f76c4);
#
#
#             var icon_c06fdbafcebcf0b658e5bf9900dab0a0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bicycle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3fd7c1e39137b719741c2294e2339353.setIcon(icon_c06fdbafcebcf0b658e5bf9900dab0a0);
#
#
#             marker_3fd7c1e39137b719741c2294e2339353.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;009-GUÉPIN&lt;/b&gt;&lt;br&gt;• 4 vélo(s) disponible(s)&lt;br&gt;• 10 place(s) disponible(s)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_afc624e1cd6f4b4c8b2a1df98cb25a33 = L.marker(
#                 [47.2225873399067, -1.55166644254598],
#                 {}
#             ).addTo(map_2c4bec57c9e6578bec0a227c3a5f76c4);
#
#
#             var icon_1f75a9085f0100286194fb8bc4215c08 = L.AwesomeMarkers.ic

# %%
#TODO : how to add a title to a Folium map ? This doesn't seem to work :
#title="TITLE"
#m.get_root().html.add_child(folium.Element(title))
